# %% [markdown]
# <a href="https://colab.research.google.com/github/Farah14-lab/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io 
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/imanges/kitten01.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/imanges/kitten01.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandrill2.tiff',img5)

#tampilkan plot dengan ukuran canvas yg lebih besar 
fig = plt.figure(figsize=(10, 10)) #ubah-ubah ukuran (10, 10) sesuai Rebutuhan
ax = fig.add_subplot (111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt dan pt2
cv.rectangle (black_img,pt1= (384, 0), pt2=(510,150), color= (0, 255, 0), thickness=10) 
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300), color=(0, 0,255), thickness=15) 
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8) 
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10, 500),fontFace=font,fontScale=4,color=(255, 255,0),thickness=2,lineType=cv.LINE_AA) 
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0, 0),pt2=(512,512), color=(255, 255, 255), thickness=5) 
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10, 500),fontFace=font,fontScale=4,color=(255, 255,0),thickness=2,lineType=cv.LINE_AA) 
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))    #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 chanel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Jawaban Pertanyaan
# 1. perbedaan gambar yang ditampilkan dengan atau tanpa matplotlib adalah matplotlib dapat digunakan untuk memvisualisasikan data secara 2D maupun 3D dengan menghasilkan gambar yang lebih berkualitas dan akan muncul grafik
# 2. perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dengan int32 adalah perbedaanya pada int16 32768 hingga 32767 dan int32 -231 hingga 231 - 1 namun untuk pengaruh pada gambarnya tidak ada
# 3.fungsi dari sintaks "google.colab.patches import cv2_imshow" adalah sebagai patches untuk menampilkan gambar di google colab yang nantinya akan ditampilkan dengan cv2_imshow
# 4. fungsi dari "skimage import io" adalah library pengolah gambar Python yang bekerja dengan numpy array yang merupakan kumpulan algoritma untuk pemrosesan gambar.

# %% [markdown]
# **TUGAS!**
# **1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?**
#
#   Jawab : Iya, berubah

# %% [markdown]
# **2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!**

# %%
img_rb = img
img_rb[:,:,1] = 0
plt.imshow(img_rb)

# %%
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %% [markdown]
# **3. Tampilkan image baris ke 20-115, kolom 25-120!**

# %%
img_k = img[20:115,25:120]
plt.imshow(img_k)

# %% [markdown]
# **4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!**

# %%
plt.imshow(img[5:30])

# %% [markdown]
# **5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!**

# %%
imageWithRectangle = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
cv.rectangle(imageWithRectangle, pt1=(500,100), pt2=(400,95), color=(0,255, 255), thickness = 20)
cv.rectangle(imageWithRectangle, pt1=(250,240), pt2=(220,500), color=(0,255,0), thickness = 40)
cv.rectangle(imageWithRectangle, pt1=(260,270), pt2=(150,170), color=(255,255,255), thickness = 20)
cv.rectangle(imageWithRectangle, pt1=(200,100), pt2=(400,600), color=(255,0,0), thickness = 25)
cv.rectangle(imageWithRectangle, pt1=(500,150), pt2=(120,750), color=(0,0,255),thickness=17)
plt.imshow(imageWithRectangle)

# %% [markdown]
# **6. Tampilkan image dengan posisi terbalik!**

# %%
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %% [markdown]
# **7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).**

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/imanges/frozen.jpeg')
fig = plt.figure(figsize=(5,5))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(75,15), pt2=(120,100), color=(220, 0, 30), thickness = 15)
cv.circle(img, center=(100, 100), radius=40, color=(180, 105, 255), thickness = 15)
ax.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %% [markdown]
# **8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/male/ female/ couple/ sailboat/ peppers!**

# %% [markdown]
# **9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.**

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/imanges/frozen.jpeg')
fig = plt.figure(figsize=(5,5))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(75,15), pt2=(120,100), color=(220, 0, 30), thickness = 15)
cv.circle(img, center=(100, 100), radius=40, color=(180, 105, 255), thickness = 15)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,text='Farah',org=(20,100),fontFace=font,fontScale=2,color=(255,255,255),thickness=2,lineType=cv.LINE_AA)
plt.imshow(img)
