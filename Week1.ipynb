# %% [markdown]
# <a href="https://colab.research.google.com/github/Farah14-lab/PCVK_Genap_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display 
from skimage import io
from skimage import transform 
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
"https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
"https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url) #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor (image, cv.COLOR_BGR2RGB) #convert color to RGB
  final_frame = cv.hconcat((image, image_2)) #concatenate image
  cv2_imshow(final_frame) #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F223A30BD60>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F223A30B730>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F21D940F8B0>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: tinggi x lebar =", tinggi, "x", lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image: tinggi x lebar = 286 x 400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F2218D47D90>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor (image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image 
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255, 255, 255]

final_frame = cv.hconcat ((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FD03C288EE0>

# %% [markdown]
# Pertanyaan :
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# Jawab : Google
# Colab memungkinkan penggunanya untuk menulis dan mengeksekusi Python di browser
# (Chrome, Firefox dan Safari) tanpa memerlukan konfigurasi, dapat mengakses GPU secara gratis,
# serta dapat berbagi kode program (kolaborasi tim) dengan mudah tanpa perlu melakukan proses instalasi selain itu, dengan menggunakan google collab dapat langsung diakses ke akun github kita jadi, semua aktivitas kita terecord secara otomatis.
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# Jawab : ya, semua library pada langkah delapan wajib kita install agar kita dapat menjalankan praktikum sesuai hasil yang kita harapkan. Penjelasan Library : numpy digunakan untuk memudahkan kita melakukan perhitungan matriks sesuai pada praktikum ini; pandas digunakan untuk memproses data, memanipulasi data, serta menganalisis data; cv2 digunakan untuk menyimpan gambar dalam format PNG; skimage atau yang biasa disebut scikit image digunakan untuk menerapkan algoritma dan utilitas; matplotlib digunakan untuk menggenerate gambar menjadi grafik.
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# Jawab : kode program tersebut digunakan untuk meriset ukuran gambar dengan ukuran panjang 0.5 dan lebar 0.5. riset ukuran gambar dilakukan agar gamabr dapat ditampilkan sesuai ukuran normal. jika tidak dilakukan maka gambar yang ditampilkan akan berukuran sangat besar dan memungkinkan gambar tidak akan bisa ditampilkan karena ukuran yang tidak sesuai.
# 4. Perhatikan potongan kode progam berikut :
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# Jawab : kode [255,255,255] adalah kode untuk membuat garis horizontal berwarna putih karena RGB dengan nominal [255,255,255] menampilkan warna putih.
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# Jawab : Didalam suatu gambar terdapat kumpulan pixel yang disebut resolusi. jika resolusi gambar semakin tinggi maka pixelnya juga semakin banyak dan gambar yang dihasilkan juga semakin tajam karena mengandung banyak warna, begitupun sebaliknya jika resolusi gambar rendah maka pixelnya semakin sedikit.

# %%
# TUGAS : 
# 1. Membuat garis vertikal pada gambar : 

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor (image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image 
for y in range (tinggi):
  image_3[y,int((lebar)/2)] = [255, 255, 255]

final_frame = cv.hconcat ((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FD03E4EFFA0>

# %%
# 2. Membuat garis menyilang diagonal pada image keluaran :
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis menyilang diagonal ditengah image
for y in range (tinggi):
  image_3[y,int(y*(lebar/tinggi))] = [255,255,255]
  image_3[y,lebar-1-int(y*(lebar/tinggi))] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FCFFDBD6A00>

# %%
# 3. Membuat garis horizontal berwarna putih dibagian tengah gambar dengan panjang tertentu  :
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal putih ditengah image dengan panjang tertentu
for y in range (0,110):
  image_3[int((lebar)/3),80+y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FCFFD4C4070>

# %%
# 4. Membuat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar :
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat kotak putih ditengah image
for x in range (100, 210):  
  for y in range(100, 210): 
    image_3[x, y] = [255,255,255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F21D9393EE0>

# %%
image_2 = cv.cvtColor (image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor (image, cv.COLOR_BGR2RGB)

#membuat garis menyilang diagonal ditengah image menggunakan perulangan x
for y in range (tinggi):
  image_3[y,int(y*(lebar/tinggi))] = [255,255,255]
  image_3[y,lebar-1-int(y*(lebar/tinggi))] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F21D9BF5460>

# %%
image_2 = cv.cvtColor (image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor (image, cv.COLOR_BGR2RGB)

#membuat garis menyilang diagonal ditengah image menggunakan perulangan y
for y in range (tinggi):
  image_3[y,int(y*(tinggi/lebar))] = [255,255,255]
  image_3[y,lebar-1-int(y*(tinggi/lebar))] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F223A30B400>
